# %%
# Python
import pandas as pd
from prophet import Prophet

# %%
# Python
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
model = Prophet()
model.fit(df)
# Out:
# 15:35:22 - cmdstanpy - INFO - Chain [1] start processing
# 15:35:24 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365)
future
# Out:
#              ds
# 0    2007-12-10
# 1    2007-12-11
# 2    2007-12-12
# 3    2007-12-13
# 4    2007-12-14
# ...         ...
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19
#
# [3270 rows x 1 columns]

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.205874    7.413661    8.911177
# 3266 2017-01-16  8.530900    7.811741    9.192265
# 3267 2017-01-17  8.318295    7.621192    9.033175
# 3268 2017-01-18  8.150892    7.415121    8.899368
# 3269 2017-01-19  8.162855    7.424499    8.895468

# %%
model.plot(forecast)

# %%
model.plot_components(forecast)

# %%
from prophet.plot import plot_plotly, plot_components_plotly

# %%
plot_components_plotly(model, forecast)
